# %%
a=5
d=150

# %%
a>d
# Out:
# False

# %%
d==a
# Out:
# False

# %%
d=a
print(a)
# Out:
# 5

# %%
d
# Out:
# 5

# %%
a<=d
# Out:
# True

# %%
a>d
# Out:
# False

# %%
a>=d
# Out:
# True

# %%
if a>d == True :
        print("yes bro")
else:
    print("sry bro")
# Out:
# sry bro

# %%
lst = range(0,)

# %%
lst
# Out:
# []
# []

# %% [markdown]
# # assignment1

# %%
while True:
    i = input()
    if i<1000 :
            print("safe to land")
    elif i == 1000:
            print ("prepare to land")
    elif 1000<i<5000:
            print ("go down to 1000")
    else:
            print('go around again')
# Out:
# 152
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
# 5
# safe to land
# safe to land
#   File "<string>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing
#   File "<string>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
i=input()

if i<1000:
    print("gain altitude")
elif i==1000:
    print("maintain altitude")
elif 1000<i and i<=5000:
            print("go down to alt1000")
elif i>5000:
                print("go around again")
# Out:
# 1000
# maintain altitude
# maintain altitude

# %% [markdown]
# # assignment 2

# %%
r = int(input("range"))
flag = 1;
for i in range (0,3):
    if(i==0 or i==1):
        print (i, " is  neither prime nor composite")
    elif (i==2):
        print(i,"is the first prime no")
    elif(i>2):
        p=0
        for c in range(3,((i//2)+1)):
            if (i%c==0): 
                p=p+1
if(p<=0):
    print(i, "is a prime no")
# Out:
# range13
# (0, ' is  neither prime nor composite')
# (1, ' is  neither prime nor composite')
# (2, 'is the first prime no')
# (2, 'is a prime no')
# (0, ' is  neither prime nor composite')
# (1, ' is  neither prime nor composite')
# (2, 'is the first prime no')
# (2, 'is a prime no')

# %%
i=7
for c in range(2,(i//2)+1,c+1):
    if (c%i==0):
        prime = 1
                 
    else:
                    prime = 0
                                        
if (prime == 0):
                    print(i)
# Out:
# 7
# 7

# %%
i=10
for c in range(1,((i//2)+1),1):
    if (c%i==0):
        prime = 1          
    else:
        prime = 0
                                        
if (prime == 1):
    print(i)

# %%
flag = 1
for c in range(2,(i//2)+1,c+1):
    if (c%i==0):
        flag=0
        break
if (flag==1):
    print(i)
# Out:
# 10
# 10

# %%
i=10;
flag = 1;
for c in range(2,(i//2)+1,1):
        if (c%i==0):
            flag = 0
if(flag == 1):
    print(i)
# Out:
# 10
# 10

# %%
2%3
# Out:
# 2
# 2

# %%
r = int(input("range"))
for i in range (2,r,):
    print(i)
    for c in range(1,((i//2)+1)):
        if (i%c==0):
             print("n")
# Out:
# range13
# 2
# n
# 3
# n
# 4
# n
# n
# 5
# n
# 6
# n
# n
# n
# 7
# n
# 8
# n
# n
# n
# 9
# n
# n
# 10
# n
# n
# n
# 11
# n
# 12
# n
# n
# n
# n
# n
# 2
# n
# 3
# n
# 4
# n
# n
# 5
# n
# 6
# n
# n
# n
# 7
# n
# 8
# n
# n
# n
# 9
# n
# n
# 10
# n
# n
# n
# 11
# n
# 12
# n
# n
# n
# n
# n

# %%
5%2
# Out:
# 1
# 1

# %%
r = int(input("range"))
for i in range (3,r):
    p=0
    for c in range(2,((i//2)+1)):
        if (i%c==0): 
            p=p+1
    if(p<=0):
        print(i)
# Out:
# range13
# 3
# 5
# 7
# 11
# 3
# 5
# 7
# 11

# %%
r = int(input("range"))
for i in range (0,r):
    if (i==0) or (i==1):
        print (i, " is  neither prime nor composite")
    else :
        for i in range(2,r):
            p=0
            for c in range(2,((i//2)+1)):
                if (i%c==0): 
                    p=p+1
            if(p<=0):
                print(i, "is a prime no")
# Out:
# range50
# (0, ' is  neither prime nor composite')
# (1, ' is  neither prime nor composite')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (0, ' is  neither prime nor composite')
# (1, ' is  neither prime nor composite')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (13, 'is a prime no')
# (17, 'is a prime no')
# (19, 'is a prime no')
# (23, 'is a prime no')
# (29, 'is a prime no')
# (31, 'is a prime no')
# (37, 'is a prime no')
# (41, 'is a prime no')
# (43, 'is a prime no')
# (47, 'is a prime no')

# %%
r = int(input("range"))
for i in range (0,r):
    if (i==0) or (i==1):
        print (i, " is  neither prime nor composite")
    else :
        p=0;
        for c in range(2,((i//2)+1)):
            if (i%c==0): 
                p=p+1
        if(p<=0):
            print(i, "is a prime no")
# Out:
# range13
# (0, ' is  neither prime nor composite')
# (1, ' is  neither prime nor composite')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
# (0, ' is  neither prime nor composite')
# (1, ' is  neither prime nor composite')
# (2, 'is a prime no')
# (3, 'is a prime no')
# (5, 'is a prime no')
# (7, 'is a prime no')
# (11, 'is a prime no')
